# %%
from openai import OpenAI
from openai.types.chat import ChatCompletionMessageParam

# %%
model_1b = 'llama3.2:1b'
base_url = 'http://localhost:11434/v1'
ollama = OpenAI(base_url=base_url, api_key='ollama')

# %%
system_message="You are helpful assistant"
system_mes=[{'role':'system','content':system_message}]

# %%
messages: list[ChatCompletionMessageParam] = [
    {'role': 'system', 'content': system_message},
    {'role': 'user', 'content': 'My name is Amer. Count number of letters in my name.'},
    {'role': 'system', 'content': 'You have 4 letters in your name - a, m, e, r'},
    {'role': 'user', 'content': 'What is my name?'}
]

# %%
stream = ollama.chat.completions.create(
    model = model_1b,
    messages = messages,  
    stream = True
)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 stream = ollama.chat.completions.create(
#       2     model = model_1b,
#       3     messages = messages,
#       4     stream = True
#       5 )
#
# File c:\Users\Amer\OneDrive\Desktop\Machine Learning\ML\.venv\lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# ...

# %%
full_text=''
for chunk in stream:
    full_text += chunk.choices[0].delta.content or ''
    print(full_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 full_text=''
# ----> 2 for chunk in stream:
#       3     full_text += chunk.choices[0].delta.content or ''
#       4     print(full_text)
#
# NameError: name 'stream' is not defined
